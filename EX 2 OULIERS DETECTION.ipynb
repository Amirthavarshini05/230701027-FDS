# %%
EX 2 OUTLIERS DETECTION
REG NO:230701027
STUDENT NAME:AMIRTHAVARSHINI R U
DATE:30/07/2024

# %%
import numpy as np
from scipy import stats
import seaborn as sns

num=np.random.randint(1,100,9)
print(num)
# Out:
# [ 9 75 97 34 45 99 21 80 91]

# %%
np.mean(num)
# Out:
# 61.22222222222222

# %%
np.median(num)
# Out:
# 75.0

# %%
stats.mode(num)
# Out:
# ModeResult(mode=9, count=1)

# %%
def out(num):
    q1=np.percentile(num,25)
    q3=np.percentile(num,75)
    iqr=q3-q1
    lb=q1-(1.5*iqr)
    ub=q3+(1.5*iqr)
    return lb,ub

# %%
lb,ub=out(num)
print(lb)
print(ub) #range for the non outliers
# Out:
# -51.5
# 176.5

# %%
sns.displot(num)
# Out:
# C:\Users\amirt_erk6tkl\anaconda3\hi\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.distplot(num)
# Out:
# C:\Users\amirt_erk6tkl\AppData\Local\Temp\ipykernel_13392\702644673.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(num)
# <Axes: ylabel='Density'>

# %%
new_num=num[(lb<num) & (num<ub)] #return a boolean array which satisfies the condition datas that are within the range
#num[(lb<num) & (num<ub)]  this gives the numbers that are true that is numbers thats satisfies the condition only true elemnts are returned
print(new_num)
# Out:
# [ 9 75 97 34 45 99 21 80 91]

# %%
lb1,lb2=out(new_num)
print(lb1)
print(lb2)
# Out:
# -51.5
# 176.5

# %%
sns.displot(new_num)
# Out:
# C:\Users\amirt_erk6tkl\anaconda3\hi\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.distplot(new_num)
# Out:
# C:\Users\amirt_erk6tkl\AppData\Local\Temp\ipykernel_13392\1576028879.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(new_num)
# <Axes: ylabel='Density'>

# %%
final_num=new_num[(lb<num) & (num<ub)] 
#2 times verification
print(final_num)
# Out:
# [ 9 75 97 34 45 99 21 80 91]

# %%
sns.displot(final_num)
# Out:
# C:\Users\amirt_erk6tkl\anaconda3\hi\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.distplot(final_num)
# Out:
# C:\Users\amirt_erk6tkl\AppData\Local\Temp\ipykernel_13392\1910024771.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(final_num)
# <Axes: ylabel='Density'>

# %%
print(final_num)
# Out:
# [ 9 75 97 34 45 99 21 80 91]
